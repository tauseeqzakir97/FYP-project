# %%
# -*- coding: utf-8 -*-

# Form implementation generated from reading ui file 'loginPage.ui'
#
# Created by: PyQt5 UI code generator 5.9.2
#
# WARNING! All changes made in this file will be lost!

from PyQt5 import QtCore, QtGui, QtWidgets

class Ui_MainWindow(object):
    def setupUi(self, MainWindow):
        MainWindow.setObjectName("MainWindow")
        MainWindow.resize(691, 321)
        MainWindow.setMaximumSize(QtCore.QSize(691, 321))
        self.centralwidget = QtWidgets.QWidget(MainWindow)
        self.centralwidget.setObjectName("centralwidget")
        self.verticalLayout_2 = QtWidgets.QVBoxLayout(self.centralwidget)
        self.verticalLayout_2.setObjectName("verticalLayout_2")
        self.verticalLayout = QtWidgets.QVBoxLayout()
        self.verticalLayout.setObjectName("verticalLayout")
        self.horizontalLayout = QtWidgets.QHBoxLayout()
        self.horizontalLayout.setObjectName("horizontalLayout")
        self.label = QtWidgets.QLabel(self.centralwidget)
        font = QtGui.QFont()
        font.setFamily("Palatino Linotype")
        font.setPointSize(16)
        self.label.setFont(font)
        self.label.setStyleSheet("margin: 10px;")
        self.label.setObjectName("label")
        self.horizontalLayout.addWidget(self.label, 0, QtCore.Qt.AlignLeft|QtCore.Qt.AlignVCenter)
        self.lineEdit = QtWidgets.QLineEdit(self.centralwidget)
        self.lineEdit.setMinimumSize(QtCore.QSize(500, 0))
        self.lineEdit.setMaximumSize(QtCore.QSize(500, 16777215))
        self.lineEdit.setStyleSheet("*{\n"
"    padding : 10px;\n"
"    margin : 20px;\n"
"}")
        self.lineEdit.setObjectName("lineEdit")
        self.horizontalLayout.addWidget(self.lineEdit)
        self.verticalLayout.addLayout(self.horizontalLayout)
        self.verticalLayout_2.addLayout(self.verticalLayout)
        self.horizontalLayout_2 = QtWidgets.QHBoxLayout()
        self.horizontalLayout_2.setObjectName("horizontalLayout_2")
        self.label_2 = QtWidgets.QLabel(self.centralwidget)
        font = QtGui.QFont()
        font.setFamily("Palatino Linotype")
        font.setPointSize(16)
        self.label_2.setFont(font)
        self.label_2.setStyleSheet("margin:10px;")
        self.label_2.setObjectName("label_2")
        self.horizontalLayout_2.addWidget(self.label_2)
        self.lineEdit_2 = QtWidgets.QLineEdit(self.centralwidget)
        self.lineEdit_2.setMinimumSize(QtCore.QSize(500, 0))
        self.lineEdit_2.setMaximumSize(QtCore.QSize(500, 16777215))
        self.lineEdit_2.setStyleSheet("*{\n"
"    padding : 10px;\n"
"    margin : 20px;\n"
"}\n"
"")
        self.lineEdit_2.setObjectName("lineEdit_2")
        self.horizontalLayout_2.addWidget(self.lineEdit_2)
        self.verticalLayout_2.addLayout(self.horizontalLayout_2)
        self.horizontalLayout_3 = QtWidgets.QHBoxLayout()
        self.horizontalLayout_3.setObjectName("horizontalLayout_3")
        self.RegisterBtn = QtWidgets.QPushButton(self.centralwidget)
        font = QtGui.QFont()
        font.setPointSize(16)
        self.RegisterBtn.setFont(font)
        self.RegisterBtn.setObjectName("RegisterBtn")
        self.horizontalLayout_3.addWidget(self.RegisterBtn)
        self.LoginBtn = QtWidgets.QPushButton(self.centralwidget)
        font = QtGui.QFont()
        font.setFamily("Palatino Linotype")
        font.setPointSize(16)
        self.LoginBtn.setFont(font)
        self.LoginBtn.setObjectName("LoginBtn")
        self.horizontalLayout_3.addWidget(self.LoginBtn)
        self.verticalLayout_2.addLayout(self.horizontalLayout_3)
        MainWindow.setCentralWidget(self.centralwidget)
        self.menubar = QtWidgets.QMenuBar(MainWindow)
        self.menubar.setGeometry(QtCore.QRect(0, 0, 691, 26))
        self.menubar.setObjectName("menubar")
        MainWindow.setMenuBar(self.menubar)
        self.statusbar = QtWidgets.QStatusBar(MainWindow)
        self.statusbar.setObjectName("statusbar")
        MainWindow.setStatusBar(self.statusbar)

        self.retranslateUi(MainWindow)
        QtCore.QMetaObject.connectSlotsByName(MainWindow)

    def retranslateUi(self, MainWindow):
        _translate = QtCore.QCoreApplication.translate
        MainWindow.setWindowTitle(_translate("MainWindow", "MainWindow"))
        self.label.setText(_translate("MainWindow", "Email : "))
        self.lineEdit.setPlaceholderText(_translate("MainWindow", "Enter your Email"))
        self.label_2.setText(_translate("MainWindow", "Password : "))
        self.lineEdit_2.setPlaceholderText(_translate("MainWindow", "Enter Your Password"))
        self.RegisterBtn.setText(_translate("MainWindow", "Register"))
        self.LoginBtn.setText(_translate("MainWindow", "Login"))

# %%
# -*- coding: utf-8 -*-

# Form implementation generated from reading ui file 'registerPage.ui'
#
# Created by: PyQt5 UI code generator 5.9.2
#
# WARNING! All changes made in this file will be lost!

from PyQt5 import QtCore, QtGui, QtWidgets

class Ui_Form(object):
    def setupUi(self, Form):
        Form.setObjectName("Form")
        Form.resize(691, 651)
        Form.setMinimumSize(QtCore.QSize(691, 651))
        Form.setMaximumSize(QtCore.QSize(691, 651))
        self.horizontalLayout = QtWidgets.QHBoxLayout(Form)
        self.horizontalLayout.setObjectName("horizontalLayout")
        self.verticalLayout_2 = QtWidgets.QVBoxLayout()
        self.verticalLayout_2.setObjectName("verticalLayout_2")
        self.horizontalLayout_3 = QtWidgets.QHBoxLayout()
        self.horizontalLayout_3.setObjectName("horizontalLayout_3")
        self.label = QtWidgets.QLabel(Form)
        font = QtGui.QFont()
        font.setPointSize(10)
        self.label.setFont(font)
        self.label.setStyleSheet("*{\n"
"margin:10px;\n"
"}")
        self.label.setObjectName("label")
        self.horizontalLayout_3.addWidget(self.label, 0, QtCore.Qt.AlignLeft)
        self.lineEdit = QtWidgets.QLineEdit(Form)
        self.lineEdit.setMinimumSize(QtCore.QSize(400, 0))
        self.lineEdit.setMaximumSize(QtCore.QSize(400, 16777215))
        self.lineEdit.setStyleSheet("*{\n"
"margin : 10px;\n"
"padding : 10px;\n"
"}")
        self.lineEdit.setObjectName("lineEdit")
        self.horizontalLayout_3.addWidget(self.lineEdit, 0, QtCore.Qt.AlignRight)
        self.verticalLayout_2.addLayout(self.horizontalLayout_3)
        self.horizontalLayout_4 = QtWidgets.QHBoxLayout()
        self.horizontalLayout_4.setObjectName("horizontalLayout_4")
        self.label_2 = QtWidgets.QLabel(Form)
        font = QtGui.QFont()
        font.setPointSize(10)
        self.label_2.setFont(font)
        self.label_2.setStyleSheet("*{\n"
"margin:10px;\n"
"}")
        self.label_2.setObjectName("label_2")
        self.horizontalLayout_4.addWidget(self.label_2, 0, QtCore.Qt.AlignLeft)
        self.lineEdit_2 = QtWidgets.QLineEdit(Form)
        self.lineEdit_2.setMinimumSize(QtCore.QSize(400, 0))
        self.lineEdit_2.setMaximumSize(QtCore.QSize(400, 16777215))
        self.lineEdit_2.setStyleSheet("*{\n"
"margin : 10px;\n"
"padding : 10px;\n"
"}")
        self.lineEdit_2.setObjectName("lineEdit_2")
        self.horizontalLayout_4.addWidget(self.lineEdit_2, 0, QtCore.Qt.AlignRight)
        self.verticalLayout_2.addLayout(self.horizontalLayout_4)
        self.horizontalLayout_5 = QtWidgets.QHBoxLayout()
        self.horizontalLayout_5.setObjectName("horizontalLayout_5")
        self.label_3 = QtWidgets.QLabel(Form)
        font = QtGui.QFont()
        font.setPointSize(10)
        self.label_3.setFont(font)
        self.label_3.setStyleSheet("*{\n"
"margin:10px;\n"
"}")
        self.label_3.setObjectName("label_3")
        self.horizontalLayout_5.addWidget(self.label_3, 0, QtCore.Qt.AlignLeft)
        self.lineEdit_3 = QtWidgets.QLineEdit(Form)
        self.lineEdit_3.setMinimumSize(QtCore.QSize(400, 0))
        self.lineEdit_3.setMaximumSize(QtCore.QSize(400, 16777215))
        self.lineEdit_3.setStyleSheet("*{\n"
"margin : 10px;\n"
"padding : 10px;\n"
"}")
        self.lineEdit_3.setObjectName("lineEdit_3")
        self.horizontalLayout_5.addWidget(self.lineEdit_3, 0, QtCore.Qt.AlignRight)
        self.verticalLayout_2.addLayout(self.horizontalLayout_5)
        self.horizontalLayout_6 = QtWidgets.QHBoxLayout()
        self.horizontalLayout_6.setObjectName("horizontalLayout_6")
        self.label_4 = QtWidgets.QLabel(Form)
        font = QtGui.QFont()
        font.setPointSize(10)
        self.label_4.setFont(font)
        self.label_4.setStyleSheet("*{\n"
"margin:10px;\n"
"}")
        self.label_4.setObjectName("label_4")
        self.horizontalLayout_6.addWidget(self.label_4, 0, QtCore.Qt.AlignLeft)
        self.lineEdit_4 = QtWidgets.QLineEdit(Form)
        self.lineEdit_4.setMinimumSize(QtCore.QSize(400, 0))
        self.lineEdit_4.setMaximumSize(QtCore.QSize(400, 16777215))
        self.lineEdit_4.setStyleSheet("*{\n"
"margin : 10px;\n"
"padding : 10px;\n"
"}")
        self.lineEdit_4.setObjectName("lineEdit_4")
        self.horizontalLayout_6.addWidget(self.lineEdit_4, 0, QtCore.Qt.AlignRight)
        self.verticalLayout_2.addLayout(self.horizontalLayout_6)
        self.horizontalLayout_7 = QtWidgets.QHBoxLayout()
        self.horizontalLayout_7.setObjectName("horizontalLayout_7")
        self.label_5 = QtWidgets.QLabel(Form)
        font = QtGui.QFont()
        font.setPointSize(10)
        self.label_5.setFont(font)
        self.label_5.setStyleSheet("*{\n"
"margin:10px;\n"
"}")
        self.label_5.setObjectName("label_5")
        self.horizontalLayout_7.addWidget(self.label_5, 0, QtCore.Qt.AlignLeft)
        self.lineEdit_5 = QtWidgets.QLineEdit(Form)
        self.lineEdit_5.setMinimumSize(QtCore.QSize(400, 0))
        self.lineEdit_5.setMaximumSize(QtCore.QSize(400, 16777215))
        self.lineEdit_5.setStyleSheet("*{\n"
"margin : 10px;\n"
"padding : 10px;\n"
"}")
        self.lineEdit_5.setObjectName("lineEdit_5")
        self.horizontalLayout_7.addWidget(self.lineEdit_5, 0, QtCore.Qt.AlignRight)
        self.verticalLayout_2.addLayout(self.horizontalLayout_7)
        self.horizontalLayout_8 = QtWidgets.QHBoxLayout()
        self.horizontalLayout_8.setObjectName("horizontalLayout_8")
        self.label_6 = QtWidgets.QLabel(Form)
        font = QtGui.QFont()
        font.setPointSize(10)
        self.label_6.setFont(font)
        self.label_6.setStyleSheet("*{\n"
"margin:10px;\n"
"}")
        self.label_6.setObjectName("label_6")
        self.horizontalLayout_8.addWidget(self.label_6, 0, QtCore.Qt.AlignLeft)
        self.lineEdit_6 = QtWidgets.QLineEdit(Form)
        self.lineEdit_6.setMinimumSize(QtCore.QSize(400, 0))
        self.lineEdit_6.setMaximumSize(QtCore.QSize(400, 16777215))
        self.lineEdit_6.setStyleSheet("*{\n"
"margin : 10px;\n"
"padding : 10px;\n"
"}")
        self.lineEdit_6.setObjectName("lineEdit_6")
        self.horizontalLayout_8.addWidget(self.lineEdit_6, 0, QtCore.Qt.AlignRight)
        self.verticalLayout_2.addLayout(self.horizontalLayout_8)
        self.horizontalLayout_10 = QtWidgets.QHBoxLayout()
        self.horizontalLayout_10.setObjectName("horizontalLayout_10")
        self.label_7 = QtWidgets.QLabel(Form)
        font = QtGui.QFont()
        font.setPointSize(10)
        self.label_7.setFont(font)
        self.label_7.setStyleSheet("*{\n"
"margin:10px;\n"
"}")
        self.label_7.setObjectName("label_7")
        self.horizontalLayout_10.addWidget(self.label_7)
        self.ChooseImage = QtWidgets.QPushButton(Form)
        font = QtGui.QFont()
        font.setPointSize(10)
        self.ChooseImage.setFont(font)
        self.ChooseImage.setObjectName("ChooseImage")
        self.horizontalLayout_10.addWidget(self.ChooseImage, 0, QtCore.Qt.AlignHCenter)
        self.verticalLayout_2.addLayout(self.horizontalLayout_10)
        self.horizontalLayout_9 = QtWidgets.QHBoxLayout()
        self.horizontalLayout_9.setObjectName("horizontalLayout_9")
        self.RegisterBtn = QtWidgets.QPushButton(Form)
        font = QtGui.QFont()
        font.setPointSize(10)
        self.RegisterBtn.setFont(font)
        self.RegisterBtn.setObjectName("RegisterBtn")
        self.horizontalLayout_9.addWidget(self.RegisterBtn, 0, QtCore.Qt.AlignHCenter)
        self.verticalLayout_2.addLayout(self.horizontalLayout_9)
        self.horizontalLayout.addLayout(self.verticalLayout_2)

        self.retranslateUi(Form)
        QtCore.QMetaObject.connectSlotsByName(Form)

    def retranslateUi(self, Form):
        _translate = QtCore.QCoreApplication.translate
        Form.setWindowTitle(_translate("Form", "Form"))
        self.label.setText(_translate("Form", "Enter Your First Name : "))
        self.lineEdit.setPlaceholderText(_translate("Form", "Enter your First Name"))
        self.label_2.setText(_translate("Form", "Enter You Last Name : "))
        self.lineEdit_2.setPlaceholderText(_translate("Form", "Enter your Last Name"))
        self.label_3.setText(_translate("Form", "Enter Your Email : "))
        self.lineEdit_3.setPlaceholderText(_translate("Form", "Enter your Email"))
        self.label_4.setText(_translate("Form", "Enter Your Password : "))
        self.lineEdit_4.setPlaceholderText(_translate("Form", "Enter your Password"))
        self.label_5.setText(_translate("Form", "Re-Enter Your Password : "))
        self.lineEdit_5.setPlaceholderText(_translate("Form", "Re-Enter your Password"))
        self.label_6.setText(_translate("Form", "Enter Your 4 Digit Pin Code : "))
        self.lineEdit_6.setPlaceholderText(_translate("Form", "Enter 4 digit Pin Code"))
        self.label_7.setText(_translate("Form", "Select Signature Image : "))
        self.ChooseImage.setText(_translate("Form", "Choose Folder"))
        self.RegisterBtn.setText(_translate("Form", "Register Now!"))

# %%
# -*- coding: utf-8 -*-

# Form implementation generated from reading ui file 'liveSignatureScreen.ui'
#
# Created by: PyQt5 UI code generator 5.9.2
#
# WARNING! All changes made in this file will be lost!

from PyQt5 import QtCore, QtGui, QtWidgets

class Ui_LiveSignature(object):
    def setupUi(self, MainWindow):
        MainWindow.setObjectName("MainWindow")
        MainWindow.resize(574, 351)
        MainWindow.setMinimumSize(QtCore.QSize(554, 351))
        MainWindow.setMaximumSize(QtCore.QSize(574, 351))
        self.centralwidget = QtWidgets.QWidget(MainWindow)
        self.centralwidget.setObjectName("centralwidget")
        self.verticalLayout = QtWidgets.QVBoxLayout(self.centralwidget)
        self.verticalLayout.setObjectName("verticalLayout")
        self.verticalLayout_2 = QtWidgets.QVBoxLayout()
        self.verticalLayout_2.setObjectName("verticalLayout_2")
        self.horizontalLayout = QtWidgets.QHBoxLayout()
        self.horizontalLayout.setObjectName("horizontalLayout")
        self.label_5 = QtWidgets.QLabel(self.centralwidget)
        font = QtGui.QFont()
        font.setPointSize(12)
        self.label_5.setFont(font)
        self.label_5.setObjectName("label_5")
        self.horizontalLayout.addWidget(self.label_5)
        self.prediction = QtWidgets.QLabel(self.centralwidget)
        font = QtGui.QFont()
        font.setPointSize(10)
        self.prediction.setFont(font)
        self.prediction.setObjectName("prediction")
        self.horizontalLayout.addWidget(self.prediction)
        self.label = QtWidgets.QLabel(self.centralwidget)
        font = QtGui.QFont()
        font.setPointSize(12)
        self.label.setFont(font)
        self.label.setObjectName("label")
        self.horizontalLayout.addWidget(self.label)
        self.accuracy = QtWidgets.QLabel(self.centralwidget)
        font = QtGui.QFont()
        font.setPointSize(10)
        self.accuracy.setFont(font)
        self.accuracy.setObjectName("accuracy")
        self.horizontalLayout.addWidget(self.accuracy)
        self.verticalLayout_2.addLayout(self.horizontalLayout)
        self.inputDigit = QtWidgets.QPushButton(self.centralwidget)
        self.inputDigit.setMinimumSize(QtCore.QSize(554, 0))
        font = QtGui.QFont()
        font.setPointSize(12)
        self.inputDigit.setFont(font)
        self.inputDigit.setObjectName("inputDigit")
        self.verticalLayout_2.addWidget(self.inputDigit)
        self.resultBtn = QtWidgets.QPushButton(self.centralwidget)
        font = QtGui.QFont()
        font.setPointSize(12)
        self.resultBtn.setFont(font)
        self.resultBtn.setObjectName("resultBtn")
        self.verticalLayout_2.addWidget(self.resultBtn)
        self.verticalLayout.addLayout(self.verticalLayout_2)
        MainWindow.setCentralWidget(self.centralwidget)
        self.menubar = QtWidgets.QMenuBar(MainWindow)
        self.menubar.setGeometry(QtCore.QRect(0, 0, 574, 26))
        self.menubar.setObjectName("menubar")
        MainWindow.setMenuBar(self.menubar)
        self.statusbar = QtWidgets.QStatusBar(MainWindow)
        self.statusbar.setObjectName("statusbar")
        MainWindow.setStatusBar(self.statusbar)

        self.retranslateUi(MainWindow)
        QtCore.QMetaObject.connectSlotsByName(MainWindow)

    def retranslateUi(self, MainWindow):
        _translate = QtCore.QCoreApplication.translate
        MainWindow.setWindowTitle(_translate("MainWindow", "MainWindow"))
        self.label_5.setText(_translate("MainWindow", "Prediction :"))
        self.prediction.setText(_translate("MainWindow", "0"))
        self.label.setText(_translate("MainWindow", "Accuracy :"))
        self.accuracy.setText(_translate("MainWindow", "0%"))
        self.inputDigit.setText(_translate("MainWindow", "Input Signature"))
        self.resultBtn.setText(_translate("MainWindow", "Get Results"))

# %%
# -*- coding: utf-8 -*-

# Form implementation generated from reading ui file 'home.ui'
#
# Created by: PyQt5 UI code generator 5.9.2
#
# WARNING! All changes made in this file will be lost!

from PyQt5 import QtCore, QtGui, QtWidgets

class Ui_Home(object):
    def setupUi(self, Form):
        Form.setObjectName("Form")
        Form.resize(400, 300)
        Form.setMinimumSize(QtCore.QSize(400, 300))
        Form.setMaximumSize(QtCore.QSize(400, 300))
        Form.setStyleSheet("*{\n"
"padding : 10px;\n"
"margin: 10px;\n"
"}")
        self.verticalLayout = QtWidgets.QVBoxLayout(Form)
        self.verticalLayout.setObjectName("verticalLayout")
        self.pushButton = QtWidgets.QPushButton(Form)
        font = QtGui.QFont()
        font.setPointSize(10)
        self.pushButton.setFont(font)
        self.pushButton.setObjectName("pushButton")
        self.verticalLayout.addWidget(self.pushButton)
        self.pushButton_3 = QtWidgets.QPushButton(Form)
        font = QtGui.QFont()
        font.setPointSize(10)
        self.pushButton_3.setFont(font)
        self.pushButton_3.setObjectName("pushButton_3")
        self.verticalLayout.addWidget(self.pushButton_3)
        self.pushButton_2 = QtWidgets.QPushButton(Form)
        font = QtGui.QFont()
        font.setPointSize(10)
        self.pushButton_2.setFont(font)
        self.pushButton_2.setObjectName("pushButton_2")
        self.verticalLayout.addWidget(self.pushButton_2)

        self.retranslateUi(Form)
        QtCore.QMetaObject.connectSlotsByName(Form)

    def retranslateUi(self, Form):
        _translate = QtCore.QCoreApplication.translate
        Form.setWindowTitle(_translate("Form", "Form"))
        self.pushButton.setText(_translate("Form", "Live Digit Prediction"))
        self.pushButton_3.setText(_translate("Form", "Live Signature Prediction"))
        self.pushButton_2.setText(_translate("Form", "Document Verification"))

# %%
# -*- coding: utf-8 -*-

# Form implementation generated from reading ui file 'documentScreen.ui'
#
# Created by: PyQt5 UI code generator 5.9.2
#
# WARNING! All changes made in this file will be lost!

from PyQt5 import QtCore, QtGui, QtWidgets

class Ui_DocumentScreen(object):
    def setupUi(self, MainWindow):
        MainWindow.setObjectName("MainWindow")
        MainWindow.resize(554, 351)
        MainWindow.setMaximumSize(QtCore.QSize(554, 351))
        self.centralwidget = QtWidgets.QWidget(MainWindow)
        self.centralwidget.setObjectName("centralwidget")
        self.verticalLayout = QtWidgets.QVBoxLayout(self.centralwidget)
        self.verticalLayout.setObjectName("verticalLayout")
        self.horizontalLayout = QtWidgets.QHBoxLayout()
        self.horizontalLayout.setObjectName("horizontalLayout")
        self.label_5 = QtWidgets.QLabel(self.centralwidget)
        font = QtGui.QFont()
        font.setPointSize(12)
        self.label_5.setFont(font)
        self.label_5.setObjectName("label_5")
        self.horizontalLayout.addWidget(self.label_5)
        self.prediction = QtWidgets.QLabel(self.centralwidget)
        font = QtGui.QFont()
        font.setPointSize(10)
        self.prediction.setFont(font)
        self.prediction.setObjectName("prediction")
        self.horizontalLayout.addWidget(self.prediction)
        self.label = QtWidgets.QLabel(self.centralwidget)
        font = QtGui.QFont()
        font.setPointSize(12)
        self.label.setFont(font)
        self.label.setObjectName("label")
        self.horizontalLayout.addWidget(self.label)
        self.accuracy = QtWidgets.QLabel(self.centralwidget)
        font = QtGui.QFont()
        font.setPointSize(10)
        self.accuracy.setFont(font)
        self.accuracy.setObjectName("accuracy")
        self.horizontalLayout.addWidget(self.accuracy)
        self.verticalLayout.addLayout(self.horizontalLayout)
        self.verticalLayout_2 = QtWidgets.QVBoxLayout()
        self.verticalLayout_2.setObjectName("verticalLayout_2")
        self.inputDigit = QtWidgets.QPushButton(self.centralwidget)
        font = QtGui.QFont()
        font.setPointSize(12)
        self.inputDigit.setFont(font)
        self.inputDigit.setObjectName("inputDigit")
        self.verticalLayout_2.addWidget(self.inputDigit)
        self.verticalLayout.addLayout(self.verticalLayout_2)
        MainWindow.setCentralWidget(self.centralwidget)
        self.menubar = QtWidgets.QMenuBar(MainWindow)
        self.menubar.setGeometry(QtCore.QRect(0, 0, 554, 26))
        self.menubar.setObjectName("menubar")
        MainWindow.setMenuBar(self.menubar)
        self.statusbar = QtWidgets.QStatusBar(MainWindow)
        self.statusbar.setObjectName("statusbar")
        MainWindow.setStatusBar(self.statusbar)

        self.retranslateUi(MainWindow)
        QtCore.QMetaObject.connectSlotsByName(MainWindow)

    def retranslateUi(self, MainWindow):
        _translate = QtCore.QCoreApplication.translate
        MainWindow.setWindowTitle(_translate("MainWindow", "MainWindow"))
        self.label_5.setText(_translate("MainWindow", "Prediction :"))
        self.prediction.setText(_translate("MainWindow", "0"))
        self.label.setText(_translate("MainWindow", "Accuracy :"))
        self.accuracy.setText(_translate("MainWindow", "0%"))
        self.inputDigit.setText(_translate("MainWindow", "Input Document"))

# %%
import os

from PyQt5.QtWidgets import *
from PyQt5.QtGui import *
from PyQt5.QtCore import *
from PyQt5.QtSql import QSqlDatabase, QSqlQuery
import sys

from loginPage import Ui_MainWindow
from registerPage import Ui_Form
from home import Ui_Home
from LiveDigitScreen import  Ui_LiveDigit
from liveSignatureScreen import Ui_LiveSignature
from documentScreen import Ui_DocumentScreen


class DocumentScreen(QMainWindow):
    def __init__(self):
        QMainWindow.__init__(self)
        self.canvas = Canvas()
        self.ui = Ui_DocumentScreen()
        self.ui.setupUi(self)
        self.ui.inputDigit.clicked.connect(self.open_file)

    def open_file(self):
        file, check = QFileDialog.getOpenFileName(self, "QFileDialog.getOpenFileName()",
                                                       "", "Image files (*.jpg *.png *.jpeg)")
        print(file)


class LiveSignaturePrediction(QMainWindow):
    def __init__(self):
        QMainWindow.__init__(self)
        self.canvas = Canvas()
        self.ui = Ui_LiveSignature()
        self.ui.setupUi(self)
        self.ui.inputDigit.clicked.connect(self.open_canvas)
        self.ui.resultBtn.clicked.connect(self.result)

    def open_canvas(self):
        self.canvas.show()

    def result(self):
        print("hy")
        filePath = os.getcwd()
        finalPath =  filePath + r"\image.png"
        print(finalPath)
        file = open(finalPath, 'r')
        print(file)


class LiveDigitPrediction(QMainWindow):
    def __init__(self):
        QMainWindow.__init__(self)
        self.canvas = Canvas()
        self.ui = Ui_LiveDigit()
        self.ui.setupUi(self)
        self.ui.inputDigit.clicked.connect(self.open_canvas)
        self.ui.resultBtn.clicked.connect(self.result)

    def open_canvas(self):
        self.canvas.show()
    

    def result(self):
        print("hy")
        filePath = os.getcwd()
        finalPath =  filePath + r"\image.png"
        print(finalPath)
        file = open(finalPath, 'r')
        print(file)
        self.ui.accuracy.setText("50")
        self.ui.prediction.setText("1")


class Canvas(QWidget):
    def __init__(self):
        QWidget.__init__(self)

        self.drawing = False
        self.lastPoint = QPoint()

        myCanvas = QImage(self.size(), QImage.Format_RGB32)
        myCanvas.fill(Qt.black)
        self.image = QPixmap(myCanvas)
        self.setGeometry(100, 100, 500, 300)
        self.resize(self.image.width(), self.image.height())

    def paintEvent(self, event):
        painter = QPainter(self)
        painter.drawPixmap(self.rect(), self.image)

    def mousePressEvent(self, event):
        if event.button() == Qt.LeftButton:
            self.drawing = True
            self.lastPoint = event.pos()

    def mouseMoveEvent(self, event):
        if event.buttons() and Qt.LeftButton and self.drawing:
            painter = QPainter(self.image)
            painter.setPen(QPen(Qt.white, 10, Qt.SolidLine))
            painter.drawLine(self.lastPoint, event.pos())
            self.lastPoint = event.pos()
            self.update()

    def mouseReleaseEvent(self, event):
        if event.button == Qt.LeftButton:
            self.drawing = False

    def save(self):
        filePath = os.getcwd()
        print(filePath + r"\image.png")
        self.image.save(filePath + r"\image.png")

    def closeEvent(self, event):
        self.save()


def show_critical_messagebox(message):
    msg = QMessageBox()
    msg.setIcon(QMessageBox.Critical)

    # setting message for Message Box
    msg.setText(message)

    # setting Message box window title
    msg.setWindowTitle("Critical MessageBox")

    # declaring buttons on Message Box
    msg.setStandardButtons(QMessageBox.Ok)

    # start the app
    retval = msg.exec_()


class HomePage(QWidget):
    def __init__(self):
        QWidget.__init__(self)
        self.digit = LiveDigitPrediction()
        self.signature = LiveSignaturePrediction()
        self.document = DocumentScreen()
        self.ui = Ui_Home()
        self.ui.setupUi(self)
        self.setWindowTitle("Signature Verification | Home")
        self.ui.pushButton.clicked.connect(self.open_digit)
        self.ui.pushButton_2.clicked.connect(self.open_document)
        self.ui.pushButton_3.clicked.connect(self.open_signature)

    def open_digit(self):
        self.hide()
        self.digit.show()

    def open_signature(self):
        self.hide()
        self.signature.show()

    def open_document(self):
        self.hide()
        self.document.show()


class RegisterPage(QWidget):
    def __init__(self):
        QWidget.__init__(self)
        self.home = HomePage()
        self.ui = Ui_Form()
        self.ui.setupUi(self)
        self.setWindowTitle("Signature Verification | Register")
        self.ui.RegisterBtn.clicked.connect(self.open_home)
        self.ui.ChooseImage.clicked.connect(self.choose_image)
        self.file = ""

    def open_home(self):
        query = QSqlQuery()
        firstName = self.ui.lineEdit.text()
        lastName = self.ui.lineEdit_2.text()
        email = self.ui.lineEdit_3.text()
        password = self.ui.lineEdit_4.text()
        rePassword = self.ui.lineEdit_5.text()
        pin = self.ui.lineEdit_6.text()
        if firstName == "" and lastName == "" and email == "" and password == "" and rePassword == "" and pin == "" and self.file == "":
            show_critical_messagebox("Fields are empty!")
        else:
            queryString = f"""INSERT INTO user (firstName, lastName, email, password, pin, signature) VALUES ('{firstName}', '{lastName}', '{email}', '{password}', '{pin}', '{self.file}');"""
            print(queryString)
            result = query.exec(
                queryString
            )
            print(result)
            self.hide()
            self.home.show()

    def choose_image(self):
        self.file = QFileDialog.getExistingDirectory(self, "Select Directory")
        print(self.file)


class LoginPage(QMainWindow):
    def __init__(self):
        QMainWindow.__init__(self)
        self.register = RegisterPage()
        self.home = HomePage()
        self.ui = Ui_MainWindow()
        self.ui.setupUi(self)
        # Set Window Tittle
        self.setWindowTitle("Signature Verification | Login")
        self.ui.LoginBtn.clicked.connect(self.open_home)
        self.ui.RegisterBtn.clicked.connect(self.open_register)
        self.show()

    def open_home(self):
        emailField = self.ui.lineEdit.text()
        passField = self.ui.lineEdit_2.text()
        if emailField != "" and passField != "":
            query = QSqlQuery()
            queryString = "SELECT  email, password FROM user where email = '" + emailField + "'"
            result = query.exec(queryString)
            if query.first() and result:
                email = query.value('email')
                password = query.value('password')
                if email == emailField and password == passField:
                    self.hide()
                    self.home.show()
                else:
                    show_critical_messagebox("Invalid password!")
            else:
                show_critical_messagebox("Email Not Found!")
        else:
            show_critical_messagebox("Fields are empty")

    def open_register(self):
        self.hide()
        self.register.show()


if __name__ == '__main__':
    app = QApplication(sys.argv)
    con = QSqlDatabase.addDatabase("QSQLITE")
    con.setDatabaseName("signature.sqlite")
    if not con.open():
        print("Database Error: %s" % con.lastError().databaseText())
        sys.exit(1)
    createTableQuery = QSqlQuery()
    createTableQuery.exec(
        """
        CREATE TABLE user (
            id INTEGER PRIMARY KEY AUTOINCREMENT UNIQUE NOT NULL,
            firstName VARCHAR(40) NOT NULL,
            lastName VARCHAR(40) NOT NULL,
            email VARCHAR(40) NOT NULL,
            password VARCHAR(40) NOT NULL,
            pin VARCHAR(5) NOT NULL,
            signature Text NOT NULL
        )
        """
    )
    print(con.tables())
    window = LoginPage()
    sys.exit(app.exec_())
# Out:
# ['user', 'sqlite_sequence']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-3189a80a684a> in clear(self)
#      43
#      44     def clear(self):
# ---> 45         self.canvas.delete('all')
#      46
#      47     def result(self):
#
# AttributeError: 'Canvas' object has no attribute 'delete'
# C:\Users\zakir\FInal FYP\UI Final\image.png
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# C:\Users\zakir\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3351: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
